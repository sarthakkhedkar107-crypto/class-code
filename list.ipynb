# %% [markdown]
# # list

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
mix = [1,15.2,10+5j,True, 'Hello']
mix
# Out:
# [1, 15.2, (10+5j), True, 'Hello']

# %%
names = ['sarthak', 'vinod', 'vishal', 'Ramesh']
names
# Out:
# ['sarthak', 'vinod', 'vishal', 'Ramesh']

# %%
names[2]
# Out:
# 'vishal'

# %%
names[1]
# Out:
# 'vinod'

# %%
names[-1]
# Out:
# 'Ramesh'

# %%
# start index ---> as it is # end index ----> +1 
s=[1,2,3,4,5,6,7]
s
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
s[1:2]
# Out:
# [2]

# %%
s[4:7]
# Out:
# [5, 6, 7]

# %%
s[0:6:2]
# Out:
# [1, 3, 5]

# %%
p=[10,20,30,40,50]
p
# Out:
# [10, 20, 30, 40, 50]

# %%
p[0:5:2]
# Out:
# [10, 30, 50]

# %%
p[::]
# Out:
# [10, 20, 30, 40, 50]

# %%
p[0::2]
# Out:
# [10, 30, 50]

# %%
p[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
p[-4:-5:-1]
# Out:
# [20]

# %%
# updating list

# %%
k=[1,2,3,4,5,6,7]
k
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
k[1]
# Out:
# 2

# %%
k[1]=100
k
# Out:
# [1, 100, 3, 4, 5, 6, 7]

# %%
k.append(7)
k
# Out:
# [1, 100, 3, 4, 5, 6, 7, 500, 7, 7]

# %%
k.append('hellow')

# %%
k
# Out:
# [1, 100, 3, 4, 5, 6, 7, 500, 7, 7, 'hellow']

# %%
k.extend('hellow')

# %%
k
# Out:
# [1, 100, 3, 4, 5, 6, 7, 500, 7, 7, 'hellow', 'h', 'e', 'l', 'l', 'o', 'w']

# %%
k.extend(5)
k
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 k.extend(5)
#       2 k
#
# TypeError: 'int' object is not iterable

# %%
k
# Out:
# [1, 100, 3, 4, 5, 6, 7, 500, 7, 7, 'hellow', 'h', 'e', 'l', 'l', 'o', 'w']

# %%
k.insert(1,1000)
k
# Out:
# [1,
#  1000,
#  1000,
#  1000,
#  100,
#  3,
#  4,
#  5,
#  6,
#  7,
#  500,
#  7,
#  7,
#  'hellow',
#  'h',
#  'e',
#  'l',
#  'l',
#  'o',
#  'w']

# %%
h=[1,2,3,4,5,6,7,8]
h
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
h.insert(1,100)
h
# Out:
# [1, 100, 100, 100, 2, 3, 4, 5, 6, 7, 8]

# %%
c=['s','k','h','p','s']
c
# Out:
# ['s', 'k', 'h', 'p', 's']

# %%
c.count('s')
# Out:
# 2

# %%
'sarthak'
# Out:
# 'sarthak'

# %%
'sarthak'
b=list('sarthak')
b
# Out:
# ['s', 'a', 'r', 't', 'h', 'a', 'k']

# %%
num=str(b)
num
# Out:
# "['s', 'a', 'r', 't', 'h', 'a', 'k']"

# %%
num.count('a')
# Out:
# 2

# %%
n = 372633723
n
# Out:
# 372633723

# %%
num=str(n)
num
# Out:
# '372633723'

# %%
num.count('3')
# Out:
# 4

# %%
n
# Out:
# 372633723

# %%
num
# Out:
# '372633723'

# %%
l=[1,222,44,5,6,7]
l
# Out:
# [1, 222, 44, 5, 6, 7]

# %%
l.index(1)
# Out:
# 0

# %%
l.remove(1)

# %%
l
# Out:
# [44, 5, 6, 7]

# %%
q=[1,2,3,4,678,88,8]
q
# Out:
# [1, 2, 3, 4, 678, 88, 8]

# %%
q.sort()
q
# Out:
# [1, 2, 3, 4, 8, 88, 678]

# %%
# Nested List

# %%
b=[1,2,3,4,[56,77,88],22,10]
b
# Out:
# [1, 2, 3, 4, [56, 77, 88], 22, 10]

# %%
b[0]
# Out:
# 1

# %%
b[4]
# Out:
# [56, 77, 88]

# %%
b[5]
# Out:
# 22
