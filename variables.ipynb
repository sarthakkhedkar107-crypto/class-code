# %%
# Addition
x=4
y=5
print(x+y)
# Out:
# 9

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# int

# %%
# multiplication
a=3
b=5
c=a*b
print(c)
# Out:
# 15

# %%
# we asign variable as (a,a_5,a5,a_5)
# eg
a=3
a5=3
a_5=3
print(a,a5,a_5)
# Out:
# 3 3 3

# %%
# we can not add variables as ( x 5,a-5,@a) that give the error becuse its case sensitive
x 5=3
a-5=3
@a=3
print(x,a-5,@a)
# Out:
#   File "/tmp/ipykernel_1550/330118630.py", line 2
#     x 5=3
#       ^
# SyntaxError: invalid syntax

# %%
name="sarthak"
name
# Out:
# 'sarthak'

# %%
last_name="khedkar"
last_name
# Out:
# 'khedkar'

# %%
type(name)
# Out:
# str

# %%
type(last_name)
# Out:
# str

# %%
name+last_name
# Out:
# 'sarthakkhedkar'

# %%
# typecasting --> changing one data type to another one
num = '5'
type(num)
# Out:
# str

# %%
# str ---> int

# %%
int(num)
# Out:
# 5

# %%
# when you give value in int() like string charchter,sentence it cant work
int("hellow")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1550/1098026388.py in <cell line: 0>()
# ----> 1 int("hellow")
#
# ValueError: invalid literal for int() with base 10: 'hellow'

# %%
str(123)
# Out:
# '123'

# %%
int(15.32324)
# Out:
# 15

# %%
float(5)
# Out:
# 5.0
