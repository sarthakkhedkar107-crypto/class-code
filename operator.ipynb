# %% [raw]
# # Arithemetic Operators

# %%
3+5
# Out:
# 8

# %%
4-1
# Out:
# 3

# %%
17*4
# Out:
# 68

# %%
10/5
# Out:
# 2.0

# %%
10%2
# Out:
# 0

# %%
"hellow" * 5
# Out:
# 'hellowhellowhellowhellowhellow'

# %%
#in python scientific language
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
# floor operator
1233 / 7
# Out:
# 176.14285714285714

# %%
1233 // 7
# Out:
# 176

# %%
123535/3
# Out:
# 41178.333333333336

# %%
123535//3
# Out:
# 41178

# %%
# power operator
2**2
# Out:
# 4

# %%
3**2
# Out:
# 9

# %%
4**2
# Out:
# 16

# %%
# task complited

# %%
# Module --> Logic even and odd code

# %%
12 % 2 #even
# Out:
# 0

# %%
13%2 #odd
# Out:
# 1

# %% [raw]
# #Assignment Operators

# %%
num1 = 5 
num1 = num1 + 1
num1
# Out:
# 6

# %%
num2=6
num2=num2-1
num2
# Out:
# 5

# %%
num3=10
num3=num3*2
num3
# Out:
# 20

# %%
num4=10
num4=num4 /2
num4
# Out:
# 5.0

# %%
num5=10
num5=num5 %2
num5
# Out:
# 0

# %%
num6=113434
num6=num6 /2
num6
# Out:
# 56717.0

# %%
num6=113434
num6=num6 //2
num6
# Out:
# 56717

# %%
num7=10
num7=num7 *2
num7
# Out:
# 20

# %%
num7=10
num7=num7 **2
num7
# Out:
# 100

# %%
#logical operator
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
# comparison Base Operator
5 > 1
# Out:
# True

# %%
5 > 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
5 >= 10
# Out:
# False

# %%
5 > 1 & 10 < 20
# Out:
# True

# %%
'hello' == 'hello'
# Out:
# True

# %%
'Hello' == 'hello'
# Out:
# False

# %%
age = 20
print('my age is',age)
# Out:
# my age is 20

# %%
name1='sarthak'
print(f'my name is {name} my age is{age}')
# Out:
# my name is sarthak my age is20

# %%
name1=input("enter your name")
print(f'my name is {name1} my age is {age}')
# Out:
# enter your name sarthak
# my name is sarthak my age is 20

# %% [markdown]
# # Data structure

# %%
#list

# %%
l=[1,2,3,4,5,6]
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(l)
# Out:
# list

# %%
mix = [1,15.2,10+5j,True, 'Hello']
mix
# Out:
# [1, 15.2, (10+5j), True, 'Hello']

# %%
type(mix)
# Out:
# list
