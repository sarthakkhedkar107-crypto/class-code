# %%
# if_Else  

if 5>10:
    print(True)
else:
    print(False)
# Out:
# False

# %%
if 40 > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Pass

# %%
marks=float(input("enter your marks"))
if marks > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# enter your marks 55
# Pass

# %%
marks=float(input("Enter your Marks"))
            
if marks >=90:
    print("A")
elif  marks>=70:
    print("b")
elif marks>=50:
    print("c")
elif marks >=35:
    print("d")
else:
    print("your Fail")
# Out:
# Enter your Marks 35
# d

# %%
# COURSE INFO

# %%
course=input("enter your course Name")

if course =='python':
    print('Yes we have python course')
elif course =='Java':
    print('We have java courese')
else:
    print(f"WE dont have {course} is")
# Out:
# enter your course Name ui
# WE dont have ui is

# %%
coupan=input("Enter coupan code")
total=float(input("Enter your Total Bill"))

if coupan=="DATA50":
    discount=total*0.5
    print(F'if you get {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
elif coupan=="DATA20":
    discount=total*0.2
    print(F'if you get {discount}')
    final_price = print(f'Your final total bill is {total - discount}')
else:
    print("we dot have coupan code")
# Out:
# Enter coupan code DATA50
# Enter your Total Bill 100
# if you get 50.0
# Your final total bill is 50.0

# %%
marks = float(input('Enter your marks'))

if marks >= 90 and marks <= 100:
    print("Grade A")
elif marks >=70 and marks <90:
    print("Grade B")
elif marks >=50 and marks <70:
    print("Grade c")
elif marks >=35 and marks<50:
    print("Grade D")
else:
    print("your Faill")
# Out:
# Enter your marks 90
# Grade A

# %%
num=int(input("enter the Number"))

if num%2==0:
    print("Even",num)
else:
    print("odd",num)
# Out:
# enter the Number 2
# Even 2
